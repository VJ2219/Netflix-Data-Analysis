# %% [markdown]
# # importing the dataset
#
# data=pd.read_csv(r'C:\Users\HP\Desktop\netflix.csv')
# data

# %% [markdown]
# # Getting some basic information about the dataset

# %%
# To show top 5 records of the dataset

data.head(5)
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
# To show bottom 5 records of the dataset

data.tail(5)
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
# To show the No.of Rows and Columns

data.shape
# Out:
# (8807, 12)

# %%
# To show the No.of elements in the dataset

data.size
# Out:
# 105684

# %%
# To show the each Columns name

data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
# To show the data types of each columns

data.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
# To show indexes,columns,data types of each column,memory

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# # Is there any duplicate records in this dataset? If yes, then remove the duplicate records.

# %%
# to c heck the row wise and detect the duplicated rows

data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
# Import seaborn library

import seaborn as sns

# %%
# To show where null value is present

data.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 7       False  False  False     False  False    False       False
# 8       False  False  False     False  False    False       False
# 9       False  False  False     False  False    False       False
# 12      False  False  False     False  False    False       False
# 24      False  False  False     False  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8801    False  False  False     False  False    False       False
# 8802    False  False  False     False  False    False       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description  Release_Year  \
# 7            False   False     False      False        False         False
# ...

# %%
# To show the count of null value present in each column

data.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# Release_Year    0
# minutes         0
# unit            0
# dtype: int64

# %%
# Using heat map to show null value counts

sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# # For 'Zombieland', what is the show id and whon is the director of this show

# %%
# To show all records of particular item in any column

data[data['title'].isin(['Zombieland'])]
# Out:
#      show_id   type       title         director  \
# 8804   s8805  Movie  Zombieland  Ruben Fleischer
#
#                                                    cast        country  \
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
#
#             date_added  release_year rating duration                listed_in  \
# 8804  November 1, 2019          2009      R   88 min  Comedies, Horror Movies
#
#                                             description Release_Year  minutes  \
# 8804  Looking to survive in a world taken over by zo...   2019-11-01       88
#
#      unit
# 8804  min

# %%
# To show all records of particular item in any column

data[data['title'].str.contains('Zombieland')]
# Out:
#      show_id   type       title         director  \
# 8804   s8805  Movie  Zombieland  Ruben Fleischer
#
#                                                    cast        country  \
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
#
#             date_added  release_year rating duration                listed_in  \
# 8804  November 1, 2019          2009      R   88 min  Comedies, Horror Movies
#
#                                             description Release_Year  minutes  \
# 8804  Looking to survive in a world taken over by zo...   2019-11-01       88
#
#      unit
# 8804  min

# %% [markdown]
# # In which year highest number of the TV shows & Movies were released? Show with bar graph.

# %%
data.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
# To create new column 


data['Release_Year']=pd.to_datetime(data['date_added'])
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
# It counts the occurence of all individual years in Date columns

data['release_year'].value_counts()
# Out:
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
#         ...
# 1959       1
# 1925       1
# 1961       1
# 1947       1
# 1966       1
# Name: release_year, Length: 74, dtype: int64

# %%
data['release_year'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# # How many Movies and TV shows are in the dataset?

# %%
# To group all unique item of a column and show their count 

data.groupby('type').type.count()
# Out:
# type
# Movie      5185
# TV Show     147
# Name: type, dtype: int64

# %% [markdown]
# # Show the all Movies that were released in year 2000

# %%
data[data['release_year'].isin([2000])]
# Out:
#      show_id     type                                              title  \
# 180     s181    Movie                 The Nutty Professor II: The Klumps
# 350     s351    Movie                                      Space Cowboys
# 359     s360    Movie                       The Original Kings of Comedy
# 566     s567    Movie                                   Charlie's Angels
# 593     s594    Movie                                           Snow Day
# 779     s780    Movie                                  Battlefield Earth
# 952     s953    Movie                               The Whole Nine Yards
# 2173   s2174  TV Show                                             Moesha
# 3472   s3473    Movie                        Rugrats in Paris: The Movie
# 4545   s4546    Movie             Monty Python: Before the Flying Circus
# 4723   s4724    Movie                                               Fiza
# 4956   s4957    Movie                        Phir Bhi Dil Hai Hindustani
# ...

# %%
data.loc[data['release_year']==2000]
# Out:
#      show_id     type                                              title  \
# 180     s181    Movie                 The Nutty Professor II: The Klumps
# 350     s351    Movie                                      Space Cowboys
# 359     s360    Movie                       The Original Kings of Comedy
# 566     s567    Movie                                   Charlie's Angels
# 593     s594    Movie                                           Snow Day
# 779     s780    Movie                                  Battlefield Earth
# 952     s953    Movie                               The Whole Nine Yards
# 2173   s2174  TV Show                                             Moesha
# 3472   s3473    Movie                        Rugrats in Paris: The Movie
# 4545   s4546    Movie             Monty Python: Before the Flying Circus
# 4723   s4724    Movie                                               Fiza
# 4956   s4957    Movie                        Phir Bhi Dil Hai Hindustani
# ...

# %% [markdown]
# # Show only the Titles of all TV Shows that were  released in India only

# %%
# To use set operators

data[data['type'].isin(['TV Show']) & data['country'].isin(['India'])] ['title']
# Out:
# 4                             Kota Factory
# 39                            Chhota Bheem
# 50                           Dharmakshetra
# 66           Raja Rasoi Aur Anya Kahaniyan
# 69          Stories by Rabindranath Tagore
#                        ...
# 8173                             Thackeray
# 8235                           The Calling
# 8321    The Golden Years with Javed Akhtar
# 8349                The House That Made Me
# 8775                       Yeh Meri Family
# Name: title, Length: 79, dtype: object

# %% [markdown]
# # Show top 10 Directors who gave the highest number of TV shows & Movies to netflix?

# %%
data['director'].value_counts().head(10)
# Out:
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: director, dtype: int64

# %% [markdown]
# # Show all the records where "type is movie and list-in is Comedies" or "country is United States"

# %%
# Filtering(And,Or Operations)

data[(data['type']=='Movie') &(data['listed_in']=='Comedies')  ]
# Out:
#      show_id   type                                   title  \
# 27       s28  Movie                               Grown Ups
# 152     s153  Movie           Janoskians: Untold and Untrue
# 182     s183  Movie             Welcome Home Roscoe Jenkins
# 342     s343  Movie                             Major Payne
# 348     s349  Movie                                    Poms
# ...      ...    ...                                     ...
# 8420   s8421  Movie              The Men Who Stare at Goats
# 8433   s8434  Movie  The Naked Gun 2 1/2: The Smell of Fear
# 8536   s8537  Movie                       The Trip to Spain
# 8608   s8609  Movie                        Total Frat Movie
# 8730   s8731  Movie                       Where's the Money
#
#                   director                                               cast  \
# 27            Dennis Dugan  Adam Sandler, Kevin James, Chris Rock, David S...
# 152           Brett Weiner  Jai Brooks, Luke Brooks, James Yammouni, Danie...
# ...

# %%
data[(data['type']=='Movie') &(data['listed_in']=='Comedies') | (data['country']=='United States')]
# Out:
#      show_id     type                 title         director  \
# 0         s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 9        s10    Movie          The Starling   Theodore Melfi
# 15       s16  TV Show     Dear White People              NaN
# 27       s28    Movie             Grown Ups     Dennis Dugan
# 28       s29    Movie            Dark Skies    Scott Stewart
# ...      ...      ...                   ...              ...
# 8791   s8792    Movie           Young Adult    Jason Reitman
# 8793   s8794    Movie  Yours, Mine and Ours     Raja Gosnell
# 8802   s8803    Movie                Zodiac    David Fincher
# 8804   s8805    Movie            Zombieland  Ruben Fleischer
# 8805   s8806    Movie                  Zoom     Peter Hewitt
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 9     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...  United States
# ...

# %% [markdown]
# # In how many movies or Tv shows ,Samuel West cast?

# %%
data[data['cast']=='Samuel West']
# Out:
#      show_id   type                                          title  \
# 7970   s7971  Movie              Secrets of Althorp - The Spencers
# 7971   s7972  Movie                          Secrets of Chatsworth
# 7972   s7973  Movie  Secrets of Henry VIII's Palace: Hampton Court
# 7973   s7974  Movie        Secrets of Her Majesty's Secret Service
# 7974   s7975  Movie                    Secrets of Highclere Castle
# 7975   s7976  Movie                       Secrets of Scotland Yard
# 7976   s7977  Movie                          Secrets of Selfridges
# 7977   s7978  Movie                 Secrets of the Tower of London
# 7978   s7979  Movie                  Secrets of Underground London
# 7979   s7980  Movie                         Secrets of Westminster
#
#                            director         cast  \
# 7970                 Kasia Uscinska  Samuel West
# 7971                  Susannah Ward  Samuel West
# 7972                     Sam Taplin  Samuel West
# ...

# %% [markdown]
# # In how many movies or Tv shows ,Tom Cruise cast?

# %%
data=data.dropna()

# %%
data[data['cast'].str.contains('Tom Cruise')]
# Out:
#      show_id   type     title              director  \
# 341     s342  Movie  Magnolia  Paul Thomas Anderson
# 1254   s1255  Movie  Rain Man        Barry Levinson
#
#                                                    cast        country  \
# 341   John C. Reilly, Philip Baker Hall, Tom Cruise,...  United States
# 1254  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#           date_added  release_year rating duration  \
# 341   August 1, 2021          1999      R  189 min
# 1254   March 1, 2021          1988      R  134 min
#
#                        listed_in  \
# 341   Dramas, Independent Movies
# 1254      Classic Movies, Dramas
#
#                                             description Release_Year
# 341   Through chance, history and divine interventio...   2021-08-01
# 1254  Motivated by money, a selfish workaholic seeki...   2021-03-01

# %% [markdown]
# #  What are the different ratings defined by ratings?

# %%
# To show the unique records

data['rating'].unique()
# Out:
# array(['TV-MA', 'TV-14', 'PG-13', 'PG', 'R', 'TV-PG', 'G', 'TV-Y7',
#        'TV-G', 'TV-Y', 'NC-17', 'NR', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
# to show the number of unique records contains in rating column

data['rating'].nunique()
# Out:
# 14

# %% [markdown]
# #  How many Movies got the 'TV-MA' rating in Canda?

# %%
data[(data['country']=='Canada') & (data['rating']=='TV-MA') & (data['type']=='Movie')]
# Out:
#      show_id   type                                              title  \
# 701     s702  Movie                                           Red Snow
# 1887   s1888  Movie  Best Wishes, Warmest Regards: A Schitt's Creek...
# 2310   s2311  Movie                       David Foster: Off the Record
# 2690   s2691  Movie                                             Code 8
# 2755   s2756  Movie                                       Indian Horse
# 2768   s2769  Movie                                        The Decline
# 3634   s3635  Movie                          The Red Sea Diving Resort
# 4093   s4094  Movie                                        Transformer
# 4686   s4687  Movie                                      One Last Shot
# 5003   s5004  Movie                                           Ravenous
# 5015   s5016  Movie                                      Swearnet Live
# 5016   s5017  Movie           Trailer Park Boys Live at the North Pole
# ...

# %%
data[(data['country']=='Canada') & (data['rating']=='TV-MA') & (data['type']=='Movie')].shape
# Out:
# (38, 13)

# %% [markdown]
# # How many TV shows got the 'TV-Y' rating after 2000?

# %%
data[(data['release_year']>=2000) & (data['rating']=='TV-Y') & (data['type']=='TV Show')]
# Out:
#      show_id     type                                       title  \
# 1463   s1464  TV Show  The Cat in the Hat Knows a Lot About That!
# 2080   s2081  TV Show                          Thomas and Friends
# 2307   s2308  TV Show                                Abby Hatcher
# 6838   s6839  TV Show                            Geronimo Stilton
# 7288   s7289  TV Show            Lego Friends: Girls on a Mission
#
#                         director  \
# 1463            Tony Collingwood
# 2080                Greg Tiernan
# 2307                 Kyran Kelly
# 6838              Guy Vasilovich
# 7288  Andrew Tan, Stephen Murray
#
#                                                    cast  \
# 1463  Martin Short, Alexa Torrington, Jacob Ewaniuk,...
# 2080  Michael Angelis, Ben Small, Keith Wickham, Ker...
# 2307  Macy Drouin, Wyatt White, Paul Sun-Hyung Lee, ...
# 6838  Brian Drummond, Erin Mathews, Richard Ian Cox,...
# 7288  Jasmine St. Clair, Allegra Clark, Rosamund Mar...
#
# ...

# %%
# What is the maximum duration of a Movies or Tv shows on Netflix?

# %%
# to get the unique duration on netflix dataset

data.duration.unique()
# Out:
# array(['125 min', '9 Seasons', '104 min', '127 min', '166 min', '103 min',
#        '97 min', '106 min', '96 min', '124 min', '116 min', '98 min',
#        '91 min', '115 min', '122 min', '99 min', '88 min', '100 min',
#        '102 min', '93 min', '95 min', '85 min', '83 min', '182 min',
#        '147 min', '90 min', '128 min', '143 min', '119 min', '114 min',
#        '118 min', '108 min', '117 min', '121 min', '142 min', '113 min',
#        '154 min', '120 min', '82 min', '94 min', '109 min', '101 min',
#        '105 min', '86 min', '229 min', '76 min', '89 min', '110 min',
#        '156 min', '112 min', '129 min', '107 min', '1 Season', '135 min',
#        '136 min', '165 min', '150 min', '133 min', '145 min', '92 min',
#        '2 Seasons', '64 min', '59 min', '111 min', '87 min', '148 min',
#        '189 min', '141 min', '130 min', '7 Seasons', '68 min', '131 min',
#        '126 min', '155 min', '123 min', '84 min', '4 Seasons', '13 min',
# ...

# %%
# to seperate the duration as minutes and unit

data[['minutes','unit']]=data['duration'].str.split(' ',expand=True)
data
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6480\425423647.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[['minutes','unit']]=data['duration'].str.split(' ',expand=True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_6480\425423647.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[['minutes','unit']]=data['duration'].str.split(' ',expand=True)
#      show_id     type                          title             director  \
# ...

# %%
# to convert the data type in object to int

data['minutes']=data['minutes'].astype(int)
data['minutes']
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6480\1301509290.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['minutes']=data['minutes'].astype(int)
# 7       125
# 8         9
# 9       104
# 12      127
# 24      166
#        ...
# 8801     96
# 8802    158
# 8804     88
# 8805     88
# 8806    111
# Name: minutes, Length: 5332, dtype: int32

# %%
data.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added              object
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# Release_Year    datetime64[ns]
# minutes                  int32
# unit                    object
# dtype: object

# %%
# maximum duration 

data['minutes'].max()
# Out:
# 253

# %%
# minimum duration

data['minutes'].min()
# Out:
# 1

# %%
# average duration

data['minutes'].mean()
# Out:
# 99.92254313578394

# %%
data['type'].value_counts()
# Out:
# Movie      5185
# TV Show     147
# Name: type, dtype: int64

# %% [markdown]
# # Which individual country has the highest number of TV Shows?

# %%
data1=data[(data['type']=='TV Show')]
data1
# Out:
#      show_id     type                                             title  \
# 8         s9  TV Show                     The Great British Baking Show
# 198     s199  TV Show              King of Boys: The Return of the King
# 273     s274  TV Show                                     Gone for Good
# 276     s277  TV Show                                           Valeria
# 297     s298  TV Show                                          Navarasa
# ...      ...      ...                                               ...
# 8172   s8173  TV Show             Th Eena Meena Deeka Chase Comedy Show
# 8214   s8215  TV Show  The Blue Planet: A Natural History of the Oceans
# 8293   s8294  TV Show                                          The Fear
# 8302   s8303  TV Show                                          The Five
# 8599   s8600  TV Show                                   Toast of London
#
#                                                director  \
# ...

# %%
data1.country.value_counts()
# Out:
# United States                                                    27
# United Kingdom                                                   19
# Japan                                                            10
# South Korea                                                      10
# Spain                                                             7
# India                                                             7
# Taiwan                                                            7
# France                                                            5
# Turkey                                                            5
# Thailand                                                          5
# Nigeria                                                           4
# Brazil                                                            4
# Canada                                                            3
# United States, Canada                                             2
# ...

# %%
data1.country.value_counts().head(1)
# Out:
# United States    27
# Name: country, dtype: int64

# %% [markdown]
# # How can we  sort the dataset by year?

# %%
data.sort_values(by='release_year',ascending=False)
# Out:
#      show_id     type                    title  \
# 1184   s1185    Movie      The Yin Yang Master
# 910     s911    Movie                  Monster
# 297     s298  TV Show                 Navarasa
# 299     s300    Movie                The Swarm
# 300     s301    Movie                     Vivo
# ...      ...      ...                      ...
# 8587   s8588    Movie              Thunderbolt
# 7294   s7295    Movie       Let There Be Light
# 7219   s7220    Movie  Know Your Enemy - Japan
# 8640   s8641    Movie         Tunisian Victory
# 8205   s8206    Movie     The Battle of Midway
#
#                                                director  \
# 1184                                          Li Weiran
# 910                                     Anthony Mandler
# 297   Bejoy Nambiar, Priyadarshan, Karthik Narain, V...
# 299                                      Just Philippot
# 300                      Kirk DeMicco, Brandon Jeffords
# ...

# %% [markdown]
# # Find all the instances where: Type is "Movie" and listed-in "Dramas" or Type is "TV Show" & listed-in "Kids' TV"

# %%
#Type is "Movie" and listed-in "Dramas"

data[(data['type']=='Movie') & (data['listed_in']=='Dramas')]
# Out:
#      show_id   type                title             director  \
# 129     s130  Movie   An Unfinished Life      Lasse Hallström
# 142     s143  Movie      Freedom Writers  Richard LaGravenese
# 162     s163  Movie             Marshall      Reginald Hudlin
# 329     s330  Movie  Catch Me If You Can     Steven Spielberg
# 343     s344  Movie              My Girl         Howard Zieff
# ...      ...    ...                  ...                  ...
# 8674   s8675  Movie      Viceroy's House      Gurinder Chadha
# 8675   s8676  Movie               Victor    Brandon Dickerson
# 8685   s8686  Movie                  VS.             Ed Lilly
# 8691   s8692  Movie            Wakefield        Robin Swicord
# 8696   s8697  Movie            War Horse     Steven Spielberg
#
#                                                    cast  \
# 129   Robert Redford, Jennifer Lopez, Morgan Freeman...
# 142   Hilary Swank, Patrick Dempsey, Scott Glenn, Im...
# ...

# %%
data[(data['type']=='TV Show') & (data['listed_in']=="Kids' TV")]
# Out:
#      show_id     type                                       title  \
# 1463   s1464  TV Show  The Cat in the Hat Knows a Lot About That!
# 2307   s2308  TV Show                                Abby Hatcher
# 5428   s5429  TV Show                               World of Winx
# 7288   s7289  TV Show            Lego Friends: Girls on a Mission
#
#                         director  \
# 1463            Tony Collingwood
# 2307                 Kyran Kelly
# 5428              Iginio Straffi
# 7288  Andrew Tan, Stephen Murray
#
#                                                    cast  \
# 1463  Martin Short, Alexa Torrington, Jacob Ewaniuk,...
# 2307  Macy Drouin, Wyatt White, Paul Sun-Hyung Lee, ...
# 5428  Haven Paschall, Alysha Deslorieux, Jessica Paq...
# 7288  Jasmine St. Clair, Allegra Clark, Rosamund Mar...
#
#                                     country        date_added  release_year  \
# 1463  Canada, United Kingdom, United States   January 1, 2021          2014
# ...

# %%
data[(data['type']=='Movie') & (data['listed_in']=='Dramas') | (data['type']=='TV Show') & (data['listed_in']=="Kids' TV")]
# Out:
#      show_id   type                title             director  \
# 129     s130  Movie   An Unfinished Life      Lasse Hallström
# 142     s143  Movie      Freedom Writers  Richard LaGravenese
# 162     s163  Movie             Marshall      Reginald Hudlin
# 329     s330  Movie  Catch Me If You Can     Steven Spielberg
# 343     s344  Movie              My Girl         Howard Zieff
# ...      ...    ...                  ...                  ...
# 8674   s8675  Movie      Viceroy's House      Gurinder Chadha
# 8675   s8676  Movie               Victor    Brandon Dickerson
# 8685   s8686  Movie                  VS.             Ed Lilly
# 8691   s8692  Movie            Wakefield        Robin Swicord
# 8696   s8697  Movie            War Horse     Steven Spielberg
#
#                                                    cast  \
# 129   Robert Redford, Jennifer Lopez, Morgan Freeman...
# 142   Hilary Swank, Patrick Dempsey, Scott Glenn, Im...
# ...
